# %% [markdown]
# ###  Base Ball Case Study

# %% [markdown]
# ####  Description

# %% [raw]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. Our Target Column is Win

# %% [markdown]
# ####  Description About Columns

# %% [raw]
# Their are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# Input features:
# Runs(R), At Bats(AB), Hits(), Doubles(2B), Triples(3B), Homeruns(H), Walks(BB), Strikeouts(SO), Stolen Bases(SB), Runs Allowed(RA), Earned Runs(ER), Earned Run Average (ERA), Shutouts(SHO), Saves, and Errors(E)
#
# Output:
# Number of predicted wins (W)

# %% [markdown]
# ###  Importing Required Liberary

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import sklearn
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ###  Loading the Dataset

# %%
df=pd.read_csv("Baseball.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# ####  We can see in our dataset 29 rows and 17 columns including target column and  their is lots of differnce in the value of columns so we do scaling in future

# %%
# Checking the data Dimension
df.shape
# Out:
# (30, 17)

# %%
# Checking Data Type of columns
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# #### We can see our all columns datatype is int and float

# %% [markdown]
# ###  Checking the Null Values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# ####  We can see thier is no null value shown at HeatMap

# %% [markdown]
# ### Statistical Summary

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# ####  We can see their is lots of difference between the min and max value so we need scaling in data set after EDA and  thier is lots of difference between mean and std so we can predict thier outliers and skweness in this dataset which is required to remove in further steps

# %% [markdown]
# ### EDA:- Exploratory Data Analysis

# %%
# Multivarrient Analysis
corr_mat=df.corr()
plt.figure(figsize=[22,12])
sns.heatmap(corr_mat,annot=True)
plt.title("Heat Map")
plt.show()

# %% [markdown]
# ####  We can see in heat map our target column is higly correlated with (BB,SHO,SV,R) columns and thier are some columns(RA,ER,ERA) from which they are highly negatively correlated .

# %%
corr_matrix=df.corr()
corr_matrix["W"].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %% [markdown]
# ####  Descending order of correlation of columns with Target column

# %%
# Bi varrient analysis
plt.scatter(x=df["SV"],y=df["W"])
plt.xlabel("SV")
plt.ylabel("W")
plt.title("W Vs SV")
plt.show()

# %% [markdown]
# ####  We can see that value of "SV" column positevely effct on value of column "W"

# %%
plt.scatter(x=df["BB"],y=df["W"])
plt.title("BB Vs W")
plt.xlabel("BB")
plt.ylabel("W")
plt.show()

# %% [markdown]
# #### We can see that value of "BB" column positevely effct on value of column "W"

# %%
import seaborn as sns
sns.distplot(df["R"],kde=True)

# %% [markdown]
# ####  We can see that in Run(R) column their are so many outliers

# %%
sns.distplot(df["BB"],kde=True)

# %% [markdown]
# ####  We have a to many points which are way above to noraml distribution , so its shown their are so many outliers in it

# %%
# Checking the Data distribution among all then column
df.plot(kind="density",subplots=True,layout=(6,12),sharex=False,legend=False,fontsize=1,figsize=(18,12))
plt.show()

# %% [markdown]
# ####  We can see that not to much skewness in the columns but thier are some column in which skewness is present we will work on it further steps

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
#Removing the skewness
x=df.drop("W",axis=1)
y=['W']
from sklearn.preprocessing import power_transform
df_new1=power_transform(x)
df_new1=pd.DataFrame(df_new1,columns=x.columns)
df_new1.skew()
# Out:
# R      0.000000
# AB     0.000000
# H      0.000000
# 2B    -0.035315
# 3B    -0.072933
# HR    -0.000065
# BB    -0.007760
# SO     0.041170
# SB    -0.010455
# RA    -0.008082
# ER    -0.001940
# ERA    0.001746
# CG    -0.059785
# SHO    0.006560
# SV     0.000836
# E      0.063909
# dtype: float64

# %% [markdown]
# ### Checking outliers

# %%
collist=df.columns.values
ncol=30
nrows=20
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color="green",orient='v')
    plt.tight_layout()

# %% [markdown]
# ###  Removing outliers

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
q1=df.quantile(0.25)
q2=df.quantile(0.75)
df_new1=df[(z<3).all(axis=1)]
df_new1
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df_new1.shape
# Out:
# (29, 17)

# %%
x=df.drop(["W"],axis=1)
y=df["W"]

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range (1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At Random State{i}the training accuracy is :- {r2_score(y_train,pred_train)}")
    print(f"At Random State{i}the testing accuracy is :- {r2_score(y_test,pred_test)}")
    print('\n')
# Out:
# At Random State1the training accuracy is :- 0.9802780428217769
# At Random State1the testing accuracy is :- 0.3146174936334326
#
#
# At Random State2the training accuracy is :- 0.9945593908141703
# At Random State2the testing accuracy is :- -2.1905436325152228
#
#
# At Random State3the training accuracy is :- 0.9760342041610787
# At Random State3the testing accuracy is :- 0.6078839601545647
#
#
# At Random State4the training accuracy is :- 0.9653607276925367
# At Random State4the testing accuracy is :- 0.6694899060031549
#
#
# At Random State5the training accuracy is :- 0.954287443943867
# At Random State5the testing accuracy is :- 0.7639635508871709
#
#
# At Random State6the training accuracy is :- 0.9548034139459601
# At Random State6the testing accuracy is :- 0.7045610801845634
#
#
# At Random State7the training accuracy is :- 0.9686347809215808
# At Random State7the testing accuracy is :- 0.5143146507033025
#
#
# At Random State8the training accuracy is :- 0.9684054066473845
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=11)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.24817597656147294

# %%
pred=lr.predict(x_test)
print("pridct the result",pred)
print("actual rings",y_test)
# Out:
# pridct the result [96.64908732 91.25103809 77.99978914 89.43928853 75.47893291 87.88714596]
# actual rings 15    100
# 8      80
# 6      87
# 26     84
# 3      76
# 11     86
# Name: W, dtype: int64

# %% [markdown]
# ### Cross Validation of the model

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold{j} the cv score is{cv_mean}and accuracy score for training is{Tarin_accuracy}and accuracy for the testing is{Test_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-d279adf2e63e> in <module>
# ----> 1 Train_accuracy=r2_score(y_train,pred_train)
#       2 Test_accuracy=r2_score(y_test,pred_test)
#       3 from sklearn.model_selection import cross_val_score
#       4 for j in range(2,10):
#       5     cv_score=cross_val_score(lr,x,y,cv=j)
#
# C:\datatrained\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# C:\datatrained\lib\site-packages\sklearn\metrics\_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     581     -3.0
#     582     """
# --> 583     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# ...

# %%
y_train.size
# Out:
# 24

# %%
pred_train.size
# Out:
# 21

# %%
x_train.size
# Out:
# 384

# %%
y_train.size
# Out:
# 24

# %%
x_test.size
# Out:
# 96

# %%
y_test.size
# Out:
# 6

# %%
pred_y.size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-9e6f90b0f50f> in <module>
# ----> 1 pred_y.size
#
# NameError: name 'pred_y' is not defined

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred_test))
# Out:
# -1.191655006420234

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(lr,x,y,cv=5)
print("Cross Validation Score of Linear regression is :-" ,scr.mean())
# Out:
# Cross Validation Score of Linear regression is :- 0.04075540667464854

# %%
from sklearn.model_selection import GridSearchCV
parameters={"max_depth":np.arange(2,15),
           "criterion":["gini",'entropy']}

# %%
GCV=GridSearchCV(LinearRegression(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-27a5a14bfcb4> in <module>
# ----> 1 GCV.fit(x_train,y_train)
#
# C:\datatrained\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# C:\datatrained\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# C:\datatrained\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
# ...

# %%
GCV.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-231e27993a13> in <module>
# ----> 1 GCV.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
from sklearn.linear_model import LinearRegression
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    LR=LinearRegression()
    LR.fit(x_train,y_train)
    predrf=LR.predict(x_test)
    acc=r2_score(y_test,predrf)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best Accuracy is ",maxAccu,"on Random_state",maxRS)
# Out:
# Best Accuracy is  0.9172122929401199 on Random_state 114

# %%
GCV=GridSearchCV(LinearRegression(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-27a5a14bfcb4> in <module>
# ----> 1 GCV.fit(x_train,y_train)
#
# C:\datatrained\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# C:\datatrained\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# C:\datatrained\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
# ...
